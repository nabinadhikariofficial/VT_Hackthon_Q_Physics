# %%
# !pip install qiskit
# !pip install pylatexenc
# !pip install qiskit_aer
# Out:
# Requirement already satisfied: qiskit in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: pylatexenc in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (2.10)
# Requirement already satisfied: qiskit_aer in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit_aer) (2.2.3)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit_aer) (2.2.6)
# Requirement already satisfied: scipy>=1.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit_aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit_aer) (7.1.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (5.5.0)
# Requirement already satisfied: typing-extensions in c:\users\peter\appdata\local\programs\python\python313\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (4.15.0)

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager

qc = QuantumCircuit(2,2,name="my_circuit")
qc.h(0)
qc.cx(0, 1)
qc.draw("mpl")

# %%
print(qc.data)
# Out:
# [CircuitInstruction(operation=Instruction(name='h', num_qubits=1, num_clbits=0, params=[]), qubits=(<Qubit register=(2, "q"), index=0>,), clbits=()), CircuitInstruction(operation=Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), qubits=(<Qubit register=(2, "q"), index=0>, <Qubit register=(2, "q"), index=1>), clbits=())]

# %%
print(circuit.global_phase)
# Out:
# 0.7853981633974483

# %%
from numpy import pi
 
circuit.global_phase = pi/4
print(circuit.global_phase)
# Out:
# 0.7853981633974483

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
 
qr1 = QuantumRegister(2)
qr2 = QuantumRegister(1)
cr1 = ClassicalRegister(2)
cr2 = ClassicalRegister(1)
qc = QuantumCircuit(qr1, qr2, cr1, cr2)
 
print("List the qubits in this circuit:", qc.qubits)
print("List the classical bits in this circuit:", qc.clbits)
# Out:
# List the qubits in this circuit: [<Qubit register=(2, "q18"), index=0>, <Qubit register=(2, "q18"), index=1>, <Qubit register=(1, "q19"), index=0>]
# List the classical bits in this circuit: [<Clbit register=(2, "c18"), index=0>, <Clbit register=(2, "c18"), index=1>, <Clbit register=(1, "c19"), index=0>]

# %%
from qiskit.circuit import QuantumCircuit
from qiskit.circuit.library import PauliEvolutionGate
from qiskit.quantum_info import SparsePauliOp
 
hamiltonian = SparsePauliOp(["ZZI", "IZZ", "IXI"], coeffs=[1, 1, -1])
gate = PauliEvolutionGate(hamiltonian)

 
circuit = QuantumCircuit(hamiltonian.num_qubits)
circuit.append(gate, circuit.qubits)
 
circuit.draw("mpl")

# %%
from qiskit.circuit.library import XGate
from qiskit.circuit.library import CXGate
gate = CXGate()


# print(gate.to_matrix())             # X gate
# print(gate.power(1/2).to_matrix())  # √X gate -- see also the SXGate
# print(gate.control(1).to_matrix())  # CX (controlled X) gate
# print(XGate().to_matrix())

print(gate.to_matrix())
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]

# %%
from qiskit.circuit.library import real_amplitudes
 
ansatz = real_amplitudes(1, entanglement="pairwise")
ansatz.draw("mpl")
